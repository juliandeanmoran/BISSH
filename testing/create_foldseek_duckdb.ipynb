# %%
import duckdb
import os

import polars as pl

from dotenv import load_dotenv

# Env
load_dotenv("../.env", override=True)
INSTALL_PATH = os.environ["INSTALL_PATH"]

# %%
# ============================================================
#                            Args
# ============================================================

args = {
    "data_file_fs_clusterSims": f"{INSTALL_PATH}/data_local/6-all-vs-all-similarity-queryId_targetId_eValue.gz",
    "db_path_fs": f"{INSTALL_PATH}/data_local/fs_clusters_db.duckdb"
    "db_path_fs_pq": f"{INSTALL_PATH}/data_local/fs_clusters_db.parquet"
}

# %%
# ============================================================
#                     Create FoldSeek DB
# ============================================================

con = duckdb.connect(args["db_path_fs"])
con.execute(f"""
CREATE TABLE IF NOT EXISTS all_vs_all_similarity AS
SELECT
    column0 AS queryID,
    column1 AS targetID,
    column2 AS eValue
FROM read_csv(
    '{args["data_file_fs_clusterSims"]}',
    delim='\t',
    header=False
)
""")

# %%
# ============================================================
#                             Test
# ============================================================

threshold = 1_000_000
result = con.execute(f"""
SELECT *
FROM {args["db_path_fs"]}
WHERE eValue >= {threshold}
""").fetchdf()
# Out:
# ---------------------------------------------------------------------------
# ParserException                           Traceback (most recent call last)
# Cell In[21], line 6
#       1 # ============================================================
#       2 #                             Test
#       3 # ============================================================
#       5 threshold = 1_000_000
# ----> 6 result = con.execute(f"""
#       7 SELECT *
#       8 FROM {args["db_path_fs"]}
#       9 WHERE eValue >= {threshold}
#      10 """).fetchdf()
#
# ParserException: Parser Error: syntax error at or near "/"
#
# LINE 3: FROM /hpf/largeprojects/tcagstor/users/juliandeanmoran/projects...
#              ^

# %%
# ============================================================
#                       Convert to parquet
# ============================================================

# %%
# !cat "../.env"
# Out:
# INSTALL_PATH="/hpf/largeprojects/tcagstor/users/juliandeanmoran/projects/BISSH"
