# %% [markdown]
# ### Explore FoldSeq datasets
# ### Julian Moran
# ### 2026-02-03

# %%
import os

import polars as pl

from dotenv import load_dotenv

# Env
load_dotenv("../.env")
INSTALL_PATH  = os.environ["INSTALL_PATH"]
# Out:
# '/home/juliandeanmoran/BISSH'

# %%
# ============================================================
#                           Args
# ============================================================
