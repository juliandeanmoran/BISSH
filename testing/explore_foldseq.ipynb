# %% [markdown]
# ### Explore FoldSeq datasets
# ### Julian Moran
# ### 2026-02-03

# %%
import os

import polars as pl

from dotenv import load_dotenv

# Env
load_dotenv("../.env")
INSTALL_PATH  = os.environ["INSTALL_PATH"]

# %%
# ============================================================
#                           Args
# ============================================================

args = {
    "data_file_cluster_IDs": f"{INSTALL_PATH}/data_sync/foldSeek_1_clusterIDs_n200_000.tsv",
    "data_file_SAP_GO": f"{INSTALL_PATH}/foldSeek_3_SAP_GOterms.tsv",
    "data_file_cluster_sims": f"{INSTALL_PATH}/foldSeek_6_clusterSims_n200_000.tsv"
}

# %%
# ============================================================
#                           In
# ============================================================

df_cluster_IDs = pl.read_csv(
    ""
)
